# %% [markdown]
# Theory Questions:

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#    - A function is a structured, reusable code block utilized for carrying out a specific task. Functions facilitate the creation of modular code, simplifying maintenance and reusability.
#    -A method is a function associated with an object that is invoked by calling the object. It is defined inside a class and typically operates on the instance of that class.

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
#   - Function arguments are values that you provide to a function when you call it. These arguments can be used by the function to perform specific tasks.
#   - When you define a function, you set up placeholders for values. These placeholders are called parameters.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
#   - Default Arguments: You can provide default values for function parameters. If an argument isn't passed when calling the
# function, the default value is used.
#   - Function with Return Value: A function can return a value using the return keyword.
#   - Function with Default Arguments: If no argument is provided, the default value is used.
#   - Function with Multiple Arguments: Python functions can accept multiple arguments.
#   - *args (Arbitrary Arguments):
#  It allows a function to accept any number of positional arguments.
#  - **kwargs (Keyword Arguments):  It allows a function to accept any number of keyword arguments.
#  The double asterisk (**) before the parameter name is used to denote that it can take multiple keyword
# arguments.
#  The arguments passed with **kwargs are treated as a dictionary.
#  - Lambda Function (Anonymous Function): A short, one-line function using lambda.

# %% [markdown]
# 4. What is the purpose of the return statement in a Python function?
#  - The return statement in Python is used to send a result back from a function to the place where the function was called.

# %% [markdown]
# 5. What are iterators in Python, and how do they differ from iterables?
#  - Iterable: An iterable is any object you can loop over using a for loop.
# Examples: list, tuple, string, set, dict, etc.
#  - An iterator is an object that keeps track of where it is in the collection. You can retrieve the next value using the next() method.It remembers the position and moves one step forward each time.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
#  - Generators are a simple way to create iterators using functions and the yield keyword instead of returning values.
#  -![unnamed.png](data:image/png;base64,...)

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
#  - Efficient Memory Usage: Generators do not store the entire sequence in memory, making them suitable for large datasets or infinite sequences.
#  - Lazy Evaluation: Generator functions follow the concept of lazy evaluation. This means that the values are generated on-the-fly and only when requested. This is particularly useful for working with large datasets or infinite sequences.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
#  - A lambda function in Python is a concise way to create anonymous functions, also known as lambda expressions.
#  Unlike regular functions defined using the def keyword, lambda functions are often used for short-term operations and are defined in a single line.
#  It is commonly used as:
#  - Arguments
#  - Expression

# %% [markdown]
# 9. Explain the purpose and usage of the map() function in Python.
#  - The map() function executes a specified function for each item in an iterable. The item is sent to the function as a parameter.
#  The map() function in Python is a built-in function that applies a given function to all the items in an iterable
# (e.g., a list) and returns an iterable map object (an iterator) of the results. Usage:
#  - function: a function (like lambda or custom def)
#  - iterable: list, tuple, etc.

# %% [markdown]
# 10. What is the difference between map(), reduce(), and filter() functions in Python?
#  - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#  - ![WhatsApp Image 2025-04-04 at 21.32.17_59f5e29f.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Practical Questions:

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.
def sum_of_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total
my_list = [1, 2, 3, 4, 5, 6]
result = sum_of_even_numbers(my_list)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 12

# %%
#2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(text):
    return text[::-1]
word = "hello"
print("Reversed string:", reverse_string(word))
# Out:
# Reversed string: olleh

# %%
#3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_numbers(numbers):
    squared_list = []
    for n in numbers:
        squared_list.append(n * n)
    return squared_list
my_list = [1, 2, 3, 4, 5]
print("Squares:", square_numbers(my_list))
# Out:
# Squares: [1, 4, 9, 16, 25]

# %%
#4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True
number = int(input("Enter a number (1 to 200): "))
if 1 <= number <= 200:
    if is_prime(number):
        print(number, "is a prime number.")
    else:
        print(number, "is not a prime number.")
else:
    print("Please enter a number between 1 and 200.")
# Out:
# Enter a number (1 to 200): 45
# 45 is not a prime number.

# %%
#5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
class Fibonacci:
    def __init__(self, terms):
        self.terms = terms
        self.a = 0
        self.b = 1
        self.count = 0
    def __iter__(self):
        return self
    def __next__(self):
        if self.count < self.terms:
            result = self.a
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return result
        else:
            raise StopIteration
n = int(input("Enter how many terms: "))
fib = Fibonacci(n)
print("Fibonacci sequence:")
for num in fib:
    print(num, end=" ")
# Out:
# Enter how many terms: 8
# Fibonacci sequence:
# 0 1 1 2 3 5 8 13

# %%
#6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_2(n):
    i = 0
    while i <= n:
        yield 2 ** i
        i += 1
exp = int(input("Enter the highest exponent: "))
print("Powers of 2:")
for num in powers_of_2(exp):
    print(num)
# Out:
# Enter the highest exponent: 5
# Powers of 2:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
#7. Implement a generator function that reads a file line by line and yields each line as a string.
def data_science_concepts_generator():
  yield "Data Exploration"
  yield "Machine Learning"
  yield "Data Visualization"
  yield "Statistics Basics"
for concept in data_science_concepts_generator():
  print(f"Understand: {concept}")
# Out:
# Understand: Data Exploration
# Understand: Machine Learning
# Understand: Data Visualization
# Understand: Statistics Basics

# %%
#8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
data = [(1, 5), (3, 2), (4, 8), (2, 1)]
sorted_data = sorted(data, key=lambda x: x[1])
print("Sorted list:", sorted_data)
# Out:
# Sorted list: [(2, 1), (3, 2), (1, 5), (4, 8)]

# %%
#9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
celsius = [0, 35, 50, 10, 42]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print("Celsius:   ", celsius)
print("Fahrenheit:", fahrenheit)
# Out:
# Celsius:    [0, 35, 50, 10, 42]
# Fahrenheit: [32.0, 95.0, 122.0, 50.0, 107.6]

# %%
#10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
def remove_vowels(text):
    return ''.join(filter(lambda ch: ch.lower() not in 'aeiou', text))
user_input = input("Enter a string: ")
result = remove_vowels(user_input)
print("Without vowels:", result)
# Out:
# Enter a string: Prayag
# Without vowels: Pryg

# %%
#11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]
order_totals = list(map(lambda x: (x[0], x[2] * x[3] + (10 if x[2] * x[3] < 100 else 0)), orders))
print(order_totals)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
